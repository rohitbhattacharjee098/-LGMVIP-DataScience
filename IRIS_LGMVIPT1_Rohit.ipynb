# %% [markdown]
# ## Rohit Bhattacharjee
# ## LGMVIP - September
# ## Task 1:Prediction using  Decision Tree Algo (IRIS dataset)

# %% [markdown]
# ## Importing the required libraries

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the Dataset

# %%
dt = pd.read_csv("Iris.csv")

# %%
dt
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dt.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dt.tail(3)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dt.drop('Id',axis=1,inplace = True)
dt.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# ## Dataset Details

# %%
dt.shape
# Out:
# (150, 5)

# %%
dt.info
# Out:
# <bound method DataFrame.info of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
dt.describe
# Out:
# <bound method NDFrame.describe of      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
for col in dt.columns:
    print(col)
# Out:
# SepalLengthCm
# SepalWidthCm
# PetalLengthCm
# PetalWidthCm
# Species

# %%
dt['Species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# ## Data Analysis(Visualization)

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.boxplot(x='Species',y='SepalLengthCm',data=dt)
plt.subplot(2,2,2)
sns.boxplot(x='Species',y='SepalWidthCm',data=dt)
plt.subplot(2,2,3)
sns.boxplot(x='Species',y='PetalLengthCm',data=dt)
plt.subplot(2,2,4)
sns.boxplot(x='Species',y= 'PetalWidthCm',data=dt)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %% [raw]
# ## compare with class

# %%
sns.stripplot(x='Species', y='SepalLengthCm', data=dt, palette='crest')
plt.title('Species vs Sepal Length')
# Out:
# Text(0.5, 1.0, 'Species vs Sepal Length')

# %%
sns.stripplot(x='Species', y='SepalWidthCm', data=dt, palette='husl')
plt.title('Species vs Sepal Width')
# Out:
# Text(0.5, 1.0, 'Species vs Sepal Width')

# %%
sns.stripplot(x='Species', y='PetalLengthCm', data=dt, palette='Paired')
plt.title('Species vs Petal Length')
# Out:
# Text(0.5, 1.0, 'Species vs Petal Length')

# %%
sns.stripplot(x='Species', y='PetalWidthCm', data=dt, palette='mako')
plt.title('Species vs Petal Width')
# Out:
# Text(0.5, 1.0, 'Species vs Petal Width')

# %%
sns.pairplot(dt, hue="Species", diag_kind="hist")

# %%
sns.pairplot(dt, kind="kde")

# %%
plt.figure(figsize=(12, 6))
matrix = dt.corr()
corMat = sns.heatmap(matrix, annot=True, cmap="mako_r")
corMat.set_title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# ## Analysis

# %%
dt.isnull().values.any()
# Out:
# False

# %%
x=dt.iloc[: , :-1].values
y=dt.iloc[: ,-1].values

# %%
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# array(['Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-setosa', 'Iris-setosa',
#        'Iris-setosa', 'Iris-setosa', 'Iris-versicolor', 'Iris-versicolor',
#        'Iris-versicolor', 'Iris-versicolor', 'Iris-versicolor',
# ...

# %% [markdown]
# ## Splitting the data into training and testing sets

# %%
X = dt.drop(['Species'], axis=1)
Y = dt['Species']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 0)

# %% [markdown]
# ## Creating  the Decision Tree Classifier

# %%
##Decision tree classifier
from sklearn.tree import DecisionTreeClassifier
decisiontree = DecisionTreeClassifier( random_state=0)

# %%
decisiontree.fit(X_train, Y_train)
Y_pred = decisiontree.predict(X_test)

# %% [markdown]
# ## Model Performance

# %%
from sklearn.metrics import confusion_matrix , accuracy_score, classification_report
cm = confusion_matrix(Y_pred , Y_test)

# %%
cm
# Out:
# array([[16,  0,  0],
#        [ 0, 17,  0],
#        [ 0,  1, 11]], dtype=int64)

# %%
cm_accuracy = round(accuracy_score(Y_pred, Y_test) , 2)*100

# %%
cm_accuracy
# Out:
# 98.0

# %%
report = classification_report(Y_pred , Y_test)
report
# Out:
# '                 precision    recall  f1-score   support\n\n    Iris-setosa       1.00      1.00      1.00        16\nIris-versicolor       0.94      1.00      0.97        17\n Iris-virginica       1.00      0.92      0.96        12\n\n       accuracy                           0.98        45\n      macro avg       0.98      0.97      0.98        45\n   weighted avg       0.98      0.98      0.98        45\n'

# %%
decisiontree = dt.copy()
decisiontree = pd.DataFrame({'Actual': Y_test, 'Predicted': Y_pred})
decisiontree.reset_index(inplace = True, drop = True)
decisiontree.sample(10)
# Out:
#              Actual        Predicted
# 35  Iris-versicolor  Iris-versicolor
# 30   Iris-virginica   Iris-virginica
# 24   Iris-virginica   Iris-virginica
# 8   Iris-versicolor  Iris-versicolor
# 28  Iris-versicolor  Iris-versicolor
# 22      Iris-setosa      Iris-setosa
# 44      Iris-setosa      Iris-setosa
# 1   Iris-versicolor  Iris-versicolor
# 42   Iris-virginica   Iris-virginica
# 21  Iris-versicolor  Iris-versicolor

# %%
print('Heatmap:\n')
from sklearn.metrics import confusion_matrix
import sklearn.metrics as metrics
plt.figure(figsize=(12, 6))
print(sns.heatmap(metrics.confusion_matrix(Y_test, Y_pred), annot = True, cmap = 'crest'))
# Out:
# Heatmap:
#
# AxesSubplot(0.125,0.125;0.62x0.755)

# %% [markdown]
# ## Thank you
